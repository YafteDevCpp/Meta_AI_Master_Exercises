# %% [markdown]
# <a href="https://colab.research.google.com/github/YafteDevCpp/Meta_AI_Master_Exercises/blob/main/Lesson_2/Hands_On_Resuelto_Lenguaje_de_Programaci%C3%B3n_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **HANDS - ON: LENGUAJE DE PROGRAMACIÓN PYTHON**

# %% [markdown]
# Una vez visto la presentación ***Lenguaje de programación python***, se proporciona el siguiente ***colab*** para que **el alumnado pueda practicar** haciendo uso del lenguaje de programación ***python***.
#
# De igual manera, se proporciona la **solución** de este notebook a través del siguiente [enlace](https://colab.research.google.com/drive/15bvIl_XYdhq9XIzj_mBSj3gw1GX592CV?usp=sharing).

# %% [markdown]
# ## **FUNDAMENTOS DE PYTHON**

# %% [markdown]
# ### **PRIMERAS PALABRAS EN PYTHON!**

# %% [markdown]
# La **función interna** `print( )` ayuda a **mostrar información** en la consola, aunque en **Google Colaboratory** se puede imprimir sin usarlo. Los textos (**cadenas de caracteres** o **Strings**) deben ir entre  **comillas dobles o simples** y no requiere de `;` al final de cada instrucción, pero es compatible si se usa.

# %%
# Imprimir 'Hola, mundo!'

print('Hola, mundo!')
# Out:
# Hola, mundo!

# %% [markdown]
# La **función interna** `input()` ayuda a **capturar texto del usuario**. Se puede **combinar con la función anterior** para obtener información específica y con el **operador de concatenación** `+` para **unir cadenas de caracteres**.

# %%
# Recibir nombre y expulsar un saludo.

nombre = input('Dame tu nombre: ')
print('Hola' + nombre)
# Out:
# Dame tu nombre: hola
# Holahola

# %% [markdown]
# Se pueden **agregar comentarios** al código usando el símbolo `#` seguido del texto y **son muy utiles para documentación**. Un comentario **no es lo mismo** que una cadena de caracteres y **se ignoran en el resultado** al ejecutarse.

# %%
# Escribir un comentario.

# Este es un comentario

'''
Este es un comentario largoooo

largooo
'''
# Out:
# '\nEste es un comentario largoooo\n\nlargooo\n'

# %% [markdown]
# ### **VARIABLES Y TIPOS DE DATOS**

# %% [markdown]
# Una **variable** es un **espacio en memoria que almacena datos**. En su definición se recomienda el **uso de nombres descriptivos a su contenido** y **no suele tener un tipo de dato predefinido**, ya que se adaptan al valor que se les asigna, y para conocerlo, se usa la **función interna** `type()`.

# %% [markdown]
# **Python** maneja diversos **típos de datos**, donde los principales son:
#
# | Nombre &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; | Típo de dato &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; |
# |------------------- | ----------- |
# | Cadena de caracter | `str`       |
# | Entero             | `int`       |
# | Flotante           | `float`     |
# | Booleano           | `bool`      |
# | Complejo           | `complex`   |
# | Lista              | `list`      |
# | Tupla              | `tuple`     |
# | Diccionario        | `dict`      |

# %%
# Escribir diferentes típos de datos
flotante = float(15.6)
palabra = str('Hola')
entero = int(2)
booleano = bool(True)
lista = list()
tupla = tuple()
diccion = dict()

print(type(flotante), type(palabra))
# Out:
# <class 'float'> <class 'str'>

# %% [markdown]
# Para realizar **operaciones aritméticas** dado los típos de datos ***int*** y ***float*** se manejan diversos **operadores**. Los principales son:
#
# | Operación Aritmética &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; | Simbolo &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; |
# |------------------- | ----------- |
# | Suma               |     `+`     |
# | Resta              |     `-`     |
# | Multiplicación     |     `*`     |
# | División           |     `/`     |
# | División entera    |    `//`     |
# | Residuo            |     `%`     |
# | Potencia           |    `**`     |

# %%
# Realizar operaciones aritméticas.

a = 4
b = 6

sum = a+b
rest = a-b
mult = a*b
div = a/b
dive = a//b
res = a%b
pot = a**b

print(sum, rest, mult, div, dive, res, pot)
# Out:
# 10 -2 24 0.6666666666666666 0 4 4096

# %% [markdown]
# Al momento de **realizar calculos matemáticos e involucrar diversos operadores**, se hace uso de la **jerarquía de operaciones** el cual define el orden de operaciones dada la regla **PEMDAS/PEDMAS**:
#
# 1.   **Paréntesis (P):** Realizar todas las operaciones dentro de los paréntesis o corchetes.
# 2.   **Exponentes (E):** Resolver los exponentes (potencias y raíces cuadradas, etc.).
# 4.   **Multiplicación y División (MD)**: Realizar de izquierda a derecha.
# 5.   **Suma y Resta (AS):** Realizar de izquierda a derecha.

# %%
# Realizar jerarquía de operaciones.

((3-2)**4 )/5 + 7
# Out:
# 7.2

# %% [markdown]
# ## **ESTRUCTURAS DE DATOS**

# %% [markdown]
# Las **estructuras de datos** son la base de la **organización y almacenamiento de información** en una computadora. Permiten **representar diferentes tipos de datos** (números, texto, objetos) de forma eficiente para su **uso y manipulación en la programación**.
#
# Las estructuras de datos fundamentales son: **listas, tuplas, conjuntos y diccionarios.**
#
# Sus operaciones fundamentales para la **gestión los datos** son ejercidos a tráves del **CRUD** (creación, lectura, actualización y eliminación).

# %% [markdown]
# ### **LISTA**

# %% [markdown]
# Una **lista** es una colección de elementos ordenados y modificables. Las listas en Python son escritas con corchetes `[]`.
#
# Algunos de sus métodos principales son:
#
# |Método     |Descripción                                              |
# | --------- |-------------------------------------------------------- |
# |`append()` |Agrega un elemento al final de la lista                  |
# |`clear()`  |Elimina todos los elementos de la lista                  |
# |`copy()`   |Devuelve una copia de la lista                           |
# |`count()`  |Devuelve el número de elementos con el valor especificado|
# |`extend()` |Agrega los elementos de una lista (o cualquier iterable), al final de la lista actual|
# |`index()`  |Devuelve el índice del primer elemento con el valor especificado|
# |`insert()` |Agrega un elemento en la posición especificada           |
# |`pop()`|Remueve el elemento en la posición especificada              |
# |`remove()` |Elimina el elemento con el valor especificado            |
# |`reverse()`|Invierte el orden de la lista                            |
# |`sort()`   |Ordena la lista                                          |

# %% [markdown]
# #### **CREACIÓN**

# %%
# Crear una lista

A = [1,3,5,7,9,11,13,15,17]
print(A)
# Out:
# [1, 3, 5, 7, 9, 11, 13, 15, 17]

# %% [markdown]
# #### **INDEXACIÓN**

# %%
# Indexar una lista
A[0]
# Out:
# 1

# %%
# Indexar una lista por rangos
A[0:4]
# Out:
# [1, 3, 5, 7]

# %% [markdown]
# #### **ACTUALIZACIÓN E INSERCIÓN**

# %%
# Actualizar elemento de una lista
A[0] = 0
print(A)
# Out:
# [0, 3, 5, 7, 9, 11, 13, 15, 17]

# %%
# Insertar elemento de una lista
A.insert(0,1) # (indice, valor)
print(A)
# Out:
# [1, 0, 3, 5, 7, 9, 11, 13, 15, 17]

# %%
# Indexar una lista de forma anidada
Anidada = [[1,2,3],[4,5,6],[7,8,9]]
Anidada[2].pop(1)
# Out:
# 8

# %% [markdown]
# #### **ELIMINACIÓN**

# %%
# Eliminar elemento de una lista usando un indice
A.remove(A[0])
print(A)
# Out:
# [0, 3, 5, 7, 9, 11, 13, 15, 17]

# %% [markdown]
# ### **DICCIONARIO**

# %% [markdown]
# Un **diccionario** es una colección de elementos desordenados, modificables e indexados. Los diccionarios en Python son escritos con llaves `{}`.
#
# Algunos de sus métodos principales son:
#
# | Función    | Descripción                                          |
# | ---------- | ---------------------------------------------------- |
# | `keys()`   | Devuelve una vista de los nombres de las claves del diccionario.|
# | `values()` | Devuelve una vista de los valores en el diccionario. |
# | `items()`  | Devuelve una vista de los pares (clave, valor) en el diccionario.|
# | `get()`    | Devuelve el valor para una clave si existe en el diccionario. |
# | `update()` | Actualiza el diccionario con los pares clave-valor especificados.|
# | `pop()`    | Elimina el elemento con la clave especificada.      |
# | `clear()`  | Elimina todos los elementos del diccionario.        |
# | `copy()`   | Devuelve una copia del diccionario.                 |

# %% [markdown]
# #### **CREACIÓN**

# %%
# Crear un diccionario

dictionary = {
    'marca': 'apple',
    'modelo': 'ipad air',
    'año': 2024
}

# %% [markdown]
# #### **INDEXACIÓN**

# %%
# Indexar un diccionario

print(dictionary['marca'])
print(dictionary['año'])
# Out:
# apple
# 2024

# %%
# Visualizar los elementos de un diccionario
print(dictionary.items())
print(dictionary.get('año'))
# Out:
# dict_items([('marca', 'apple'), ('modelo', 'ipad air'), ('año', 2024)])
# 2024

# %% [markdown]
# #### **ACTUALIZACIÓN E INSERCIÓN**

# %%
# Actualizar elemento de un diccionario
dictionary['capacidad'] = 256
dictionary['chip'] = 'M1'


print(dictionary)

dictionary['modelo'] = 'ipad pro'
dictionary.update({'año': 2021})

print(dictionary)
# Out:
# {'marca': 'apple', 'modelo': 'ipad air', 'año': 2024, 'capacidad': 256, 'chip': 'M1'}
# {'marca': 'apple', 'modelo': 'ipad pro', 'año': 2021, 'capacidad': 256, 'chip': 'M1'}

# %%
# Insertar diccionario dentro de un diccionario
dictionary["color"] = "red"
print(dictionary)
# Out:
# {'marca': 'apple', 'modelo': 'ipad pro', 'año': 2021, 'capacidad': 256, 'chip': 'M1', 'color': 'red'}

# %%
# Indexar un diccionario de forma anidada

dictionary_anid = {
    'nombre': 'Omar',
    'edad': 32,
    'datos_personales': {
        'peso': 77.2,
        'estatura': 1.80,
        'deportes': {
            'deporte1':'Tenis',
            'deporte2':'Natacion'
        }
    }
}
print(dictionary_anid['datos_personales']['deportes']['deporte2'])
# Out:
# Natacion

# %% [markdown]
# #### **ELIMINACIÓN**

# %%
# Eliminar elemento de una lista usando una clave

print(dictionary)
dictionary.pop('chip')
print(dictionary)
# Out:
# {'marca': 'apple', 'modelo': 'ipad pro', 'año': 2021, 'capacidad': 256, 'chip': 'M1', 'color': 'red'}
# {'marca': 'apple', 'modelo': 'ipad pro', 'año': 2021, 'capacidad': 256, 'color': 'red'}

# %% [markdown]
# ## **CHALLENGE: CREACIÓN DE UNA AGENDA**

# %% [markdown]
# Una vez visto el ***Hands - On: Lenguaje de programación python***, se presentan las siguientes actividades para que el alumnado pueda repasar y reforzar lo aprendido dentro de la clase.

# %% [markdown]
# Dentro de la siguiente dinámica, **se creará una agenda de tres contactos** haciendo uso de las **estructuras de datos** utilizando **Python**.
#
# Donde los datos que debe contener cada contacto de la angenda son:
#
# *   **Nombre**
# *   **Teléfono**
# *   **Correo**

# %% [markdown]
# **IMPORTANTE:** Para su revisión, **es indispensable que los apartados anteriores se encuentren llenados con el código visto durante la sesión.**

# %% [markdown]
# ### **INSTRUCCIONES:**

# %% [markdown]
# **1. Crea la Agenda:** Construye una lista vacía llamada agenda.

# %%
# Definir agenda
agenda = list()

# %% [markdown]
# **2. Crea el Primer Contacto:**
#
#    * Pide al usuario que ingrese el nombre, teléfono y correo para un contacto.
#    * Guarda estos datos en un diccionario llamado contacto_1.

# %%
# Crear el primer contacto

print('Bienvenido a tu lista de contactos \n')
nom = input('Ingresa el nombre: ')
tel = input('Ingresa telefono: ')
corr = input('Ingresa correo: ')

contacto_1 = {
    'Nombre': nom, 'Telefono': tel, 'Correo': corr
}
# Out:
# Bienvenido a tu lista de contactos
#
# Ingresa el nombre: yafte
# Ingresa telefono: 223455142
# Ingresa correo: y@python

# %% [markdown]
# **3. Crea el Segundo y Tercer Contacto:**
#
#    * Repite el proceso anterior para crear dos diccionarios más: contacto_2 y contacto_3.

# %%
# Crear el segundo contacto

print('Bienvenido a tu lista de contactos \n')
nom = input('Ingresa el nombre: ')
tel = input('Ingresa telefono: ')
corr = input('Ingresa correo: ')

contacto_2 = {
    'Nombre': nom, 'Telefono': tel, 'Correo': corr
}
# Out:
# Bienvenido a tu lista de contactos
#
# Ingresa el nombre: orlando
# Ingresa telefono: 23234554
# Ingresa correo: or@python

# %%
# Crear el tercer contacto

print('Bienvenido a tu lista de contactos \n')
nom = input('Ingresa el nombre: ')
tel = input('Ingresa telefono: ')
corr = input('Ingresa correo: ')

contacto_3 = {
    'Nombre': nom, 'Telefono': tel, 'Correo': corr
}
# Out:
# Bienvenido a tu lista de contactos
#
# Ingresa el nombre: patricia
# Ingresa telefono: 55445466
# Ingresa correo: pat@python

# %% [markdown]
# **4. Añade los Contactos a la Agenda:**
#
#    * Agrega los tres diccionarios (contacto_1, contacto_2, contacto_3) a tu lista agenda.

# %%
# Agregar contactos adentro de la agenda
agenda = [contacto_1, contacto_2, contacto_3]
agenda
# Out:
# [{'Nombre': 'yafte', 'Telefono': '223455142', 'Correo': 'y@python'},
#  {'Nombre': 'orlando', 'Telefono': '23234554', 'Correo': 'or@python'},
#  {'Nombre': 'patricia', 'Telefono': '55445466', 'Correo': 'pat@python'}]

# %% [markdown]
# **5. Modifica el Último Contacto:**
#
#    * Accede al último contacto de la agenda y modifica su teléfono y correo por nuevos valores.

# %%
# Modificar último contacto
agenda[-1]['Telefono'] = 5566673941
agenda[-1]
# Out:
# {'Nombre': 'patricia', 'Telefono': 5566673941, 'Correo': 'pat@python'}

# %% [markdown]
# **6. Muestra la Agenda Completa:**
#
#    * Imprime la lista agenda para ver el resultado final.

# %%
# Mostrar versión final de la agenda
print(agenda)
# Out:
# [{'Nombre': 'yafte', 'Telefono': '223455142', 'Correo': 'y@python'}, {'Nombre': 'orlando', 'Telefono': '23234554', 'Correo': 'or@python'}, {'Nombre': 'patricia', 'Telefono': 5566673941, 'Correo': 'pat@python'}]

# %% [markdown]
# ## Ejercicio Extra A.
#
# Crea un registro de gastos con categorías; al final imprime el total y el total por categoría.

# %%
gastos = {
    'Hogar': {'Renta': 4500, "Servicios": 1500},
    'Entretenimiento': {'Cine': 500, 'Videojuegos': 800},
    'Salud': {'Seguro': 1500, 'Consultas': 900}
}

# %%
# Claves
print('Tipos de gasto: ', gastos.keys())

# Valores
print('Gasto de cada servicio: ', gastos.values())

#Clave y Valor
print('Todo el Diccionario: ', gastos.items())
# Out:
# Tipos de gasto:  dict_keys(['Hogar', 'Entretenimiento', 'Salud'])
# Gasto de cada servicio:  dict_values([{'Renta': 4500, 'Servicios': 1500}, {'Cine': 500, 'Videojuegos': 800}, {'Seguro': 1500, 'Consultas': 900}])
# Todo el Diccionario:  dict_items([('Hogar', {'Renta': 4500, 'Servicios': 1500}), ('Entretenimiento', {'Cine': 500, 'Videojuegos': 800}), ('Salud', {'Seguro': 1500, 'Consultas': 900})])

# %%
total = 0
for categoria in gastos.values():
  for gasto in categoria.values():
      total += gasto

print('Total de Gastos: ', total, 'pesos')
# Out:
# Total de Gastos:  9700 pesos

# %% [markdown]
# ## Ejercicio Extra B.
# Construye un “perfil” con input() (nombre, edad, ciudad, hobbies) y guárdalo en un diccionario; valida edad con int().

# %%
# Obtención de datos.

print('Bienvenid@ al Creador de Perfiles. \nA continuación te pediremos la siguiente información: \n\n+ Nombre \n+ Edad \n+ Ciudad \n+ Hobbies')
print('\nEstás de acuerdo con iniciar tu perfil? \nTeclea Si o No\n')
decision = input()

if decision == 'Si' or decision == 'si':
  nombre = input('Ingresa tu nombre completo: ')
  edad = int(input('Ingresa tu edad: '))
  if not isinstance(edad, int):
    raise TypeError(
        f'{edad} debe ser de tipo {int},'
        f' pero se recibió {type(edad)}'
    )
  ciudad = input('Ingresa donde vives: ')
  hobbies = input('Ingresa tus hobbies: ')

  # Captura de datos a un diccionario
  perfil = {str(nombre): {'Nombre': nombre, "Edad": edad, "Ciudad": ciudad, "Hobbies": hobbies}}


else:
  print('\nGracias, nos vemos')
# Out:
# Bienvenid@ al Creador de Perfiles.
# A continuación te pediremos la siguiente información:
#
# + Nombre
# + Edad
# + Ciudad
# + Hobbies
#
# Estás de acuerdo con iniciar tu perfil?
# Teclea Si o No
#
# Yafte
#
# Gracias, nos vemos

# %%
perfil
# Out:
# {'Uriel Sánchez': {'Nombre': 'Uriel Sánchez',
#   'Edad': 24,
#   'Ciudad': 'CDMX',
#   'Hobbies': 'Leer'}}

# %%
'''

# Captura de datos a un diccionario.

perfiles = {}

for clave, valor in perfiles.items():
  if clave not in personas:
    personas[clave] = valor
  else:
    print(f"La persona '{clave}' ya existe. No se agregó.")
perfiles

'''
# Out:
# '\n\n# Captura de datos a un diccionario. \n\nperfiles = {}\n\nfor clave, valor in perfiles.items():\n  if clave not in personas:\n    personas[clave] = valor\n  else:\n    print(f"La persona \'{clave}\' ya existe. No se agregó.")\nperfiles\n\n'

# %% [markdown]
# ## Ejercicio Extra C.
#
# Pide 3 números al usuario, guárdalos en lista y calcula promedio; muestra el tipo de cada valor antes y después de convertir.

# %%
print('Bienvenid@ a este programa que calcula el promedio. \nA continuación te pediremos 3 numeros: ')
print('\n')

nume1 = input('Ingresa el 1er numero: ')
nume2 = input('Ingresa el 2er numero: ')
nume3 = input('Ingresa el 3er numero: ')

print('\nNúmeros que ingresaste: ', nume1 , nume2 , nume3, 'Tipo de variable: ', type(nume1),type(nume2),type(nume3) )

num1 = float(nume1)
num2 = float(nume2)
num3 = float(nume3)

num = [num1,num2,num3]

print('\nVariables convertidas: ', num1 , num2 , num3, 'Tipo de variable: ', type(num1),type(num2),type(num3) )

suma = 0
for i in num:
  suma += i
  prom = suma/len(num)

print('\nEl promedio es', prom)
# Out:
# Bienvenid@ a este programa que calcula el promedio.
# A continuación te pediremos 3 numeros:
#
#
# Ingresa el 1er numero: 24
# Ingresa el 2er numero: 20
# Ingresa el 3er numero: 1
#
# Números que ingresaste:  24 20 1 Tipo de variable:  <class 'str'> <class 'str'> <class 'str'>
#
# Variables convertidas:  24.0 20.0 1.0 Tipo de variable:  <class 'float'> <class 'float'> <class 'float'>
#
# El promedio es 15.0
